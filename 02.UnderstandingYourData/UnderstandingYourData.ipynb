# %% [markdown]
# <a href="https://colab.research.google.com/github/theMUGGLER/100daysOfML/blob/main/02.UnderstandingYourData/UnderstandingYourData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('train.csv')

# %% [markdown]
# #1. How big is the data?

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# #2. How does the data look like?

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                                   Name  \
# 379          380         0       3            Gustafsson, Mr. Karl Gideon
# 246          247         0       3  Lindahl, Miss. Agda Thorilda Viktoria
# 350          351         0       3                 Odahl, Mr. Nils Martin
# 26            27         0       3                Emir, Mr. Farred Chehab
# 418          419         0       2             Matthews, Mr. William John
#
#         Sex   Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 379    male  19.0      0      0  347069   7.775   NaN        S
# 246  female  25.0      0      0  347071   7.775   NaN        S
# 350    male  23.0      0      0    7267   9.225   NaN        S
# 26     male   NaN      0      0    2631   7.225   NaN        C
# 418    male  30.0      0      0   28228  13.000   NaN        S

# %% [markdown]
# #3. What is the data type of cols?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# #4. Are there any missing values?

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# #5. How does the data look mathematically?

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# #6. Are there duplicate values?

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #7. How is the correlation between cols?

# %%
df.corr()['Survived']
# Out:
# <ipython-input-9-57d70bb92b5b>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()['Survived']
# PassengerId   -0.005007
# Survived       1.000000
# Pclass        -0.338481
# Age           -0.077221
# SibSp         -0.035322
# Parch          0.081629
# Fare           0.257307
# Name: Survived, dtype: float64
